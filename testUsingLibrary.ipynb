# %%
import sys

# %%
sys.path
# Out:
# ['',
#  '/anaconda3/lib/python36.zip',
#  '/anaconda3/lib/python3.6',
#  '/anaconda3/lib/python3.6/lib-dynload',
#  '/anaconda3/lib/python3.6/site-packages',
#  '/anaconda3/lib/python3.6/site-packages/aeosa',
#  '/anaconda3/lib/python3.6/site-packages/matplotlib-3.1.0+1213.g63d96d286-py3.6-macosx-10.7-x86_64.egg',
#  '/anaconda3/lib/python3.6/site-packages/kiwisolver-1.1.0-py3.6-macosx-10.7-x86_64.egg',
#  '/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/Users/shaydamoezzi/.ipython']

# %%
import importingFITS
importingFITS.writingFITS('/Users/shaydamoezzi/Documents/FITS_files/PGC701_w1_bksub.fits')
# Out:
# Min: -0.031672051487238964
# Max: 152.53462974629795
# Mean: 0.017664949763020854
# Stdev: 0.7026076986272954
